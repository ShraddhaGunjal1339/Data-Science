# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
cars_data = pd.read_csv('Toyota.csv')
cars_data.dropna(axis=0, inplace=True)
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],fit_reg=False)
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
sns.displot(cars_data['Age'],kde=False)

# %%
sns.countplot(x="FuelType",data=cars_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
sns.boxplot(x=cars_data['FuelType'],y=cars_data['Price'])
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
graph = sns.FacetGrid(cars_data, col = "FuelType")
graph.map(plt.hist, "Price")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('attendance.csv',index_col='MONTH')
sns.heatmap(data,annot=True)
plt.title('Monthly Percentage Attendance')
# Out:
# Text(0.5, 1.0, 'Monthly Percentage Attendance')

# %%
sns.pairplot(cars_data,vars=['Price','Age','KM','FuelType'])
